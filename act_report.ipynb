# %% [markdown]
# # WeRateDogs Wrangle Act Report

# %% [markdown]
# ### Introduction
# The process of analyzing the **WeRateDogs** data has been one of the most interesting analysis I have performed, not only was I introduced to a way of gathering data from multiple sources but I am now confident in detecting messy and untidy data just by assessing the data either visually or programmatically. Gathering, cleaning, merging and analyzing these datasets has shown some insight on how dogs are possibly rated and how humans perceive different dog breeds and dog stages(pupper, puppo, floofer, doggo).

# %% [markdown]
# ![wrd.jpg](attachment:574b7e84-4e53-4f7e-80d6-ad41fe6ab9e7.jpg)

# %% [markdown]
# ### Insight
# ##### After gathering, assessing, cleaning and exploring the data, I have come to some conclusions.
# 1. The Dog breed with highest total rating, total likes and total retweet count on the WeRateDogs profile is Golden Retriever. From the analysis of the dataset, it is concluded that Golden Retrievers are one of the most popular breed of dogs, followed by Labrador Retriever and Pembroke. This could be due to the fact that they are hardworking, great therapy dogs and they are the cutest, in my opinion.

# %% [markdown]
# ![Pieter (haasbroekpieter) - Profile _ Pinterest.jpg](attachment:c163153f-13cf-457e-b19a-eb603537fee0.jpg)

# %% [markdown]
# ### Visualization
# ##### The chart below shows top 10 popular dog breeds in the dataset, it also shows the great difference between likes and retweet

# %% [markdown]
# ![image.png](attachment:8b3c9388-a8e1-4faf-b60e-6818b185bc4c.png)

# %% [markdown]
# ### Insight 2:
# The first dog to ever feature on the WeRateDogs profile according to the gathered dataset is a Welsh Springer Spaniel, this dog was introduced to us on 15th of November 2015, although no further information like its name and dog stage was provided in the dataset but we know he or she is a good dog with an amazing rating of 8 out of 10.

# %% [markdown]
# ![image.png](attachment:1f08d862-9700-4377-b735-788a53ab08d3.png)

# %% [markdown]
# ![image.png](attachment:f4cde32f-e97d-4a5a-b824-7455bc52e1d6.png)

# %% [markdown]
# ### Insight 3:
# 2016 was the busiest year for WeRateDogs and Mondays seem to be the day that dogs are rated the most, possibly to stimulate humans serotonin on the first day of a week. We all know Monday can be a challenging day for most people but after seeing cute and happy faces of dogs, that can put a little smile on our faces.

# %% [markdown]
# ![image.png](attachment:301985bd-62f3-482a-87ea-86c59468a2bd.png)

# %% [markdown]
# ### Visualization
# #### The chart below shows the number of dogs that have been rated on a particular day of the week with the popular days being Monday and Friday

# %% [markdown]
# ![image.png](attachment:3fe558a2-ede0-4cc2-9af8-ee0aaa03d4ff.png)

# %% [markdown]
# ### Insight 4:
# Although there wasn't enough data on the breed of the dog but with the data provided, I was able to analyze the dog breeds with low ratings(3/10 and below), these particular breeds are not bad or anything, they are just unpopular among other dog breeds and probably humans. The breeds are: Afghan Hound, Chihuahua and Maltese Dog.

# %% [markdown]
# ![15 Dog Posts From This Week That'll Make Your Day Soooo Much Better.png](attachment:f142aa16-2a87-4f1f-b8fa-d8e645c8be59.png)

# %% [markdown]
# ### Insight 5:
# Now on to the most popular dogs also known as our best boys and girls, based on number of likes and retweet. The list of the top 10 dogs are as follows:
# * Jamesy, a French Bulldog who is a pupper
# * Bo, a Standard Poodle who is a doggo
# * Sunny, a doggo
# * Barney, a Golden Retriever who is a doggo
# * Cupid, a Great Pyrenees who is a doggo
# * Astrid, a Staffordshire Bullterrier who is a doggo
# * Sebastian, a Pembroke who is a puppo
# * Cassie, a pembroke who is a doggo
# * Gabe, a Pomeranian who is a pupper
# * Gus, a Labrador Retriever who is a pupper

# %% [markdown]
# ![image.png](attachment:06ee0f05-688c-414c-89ce-3614818666b8.png)
